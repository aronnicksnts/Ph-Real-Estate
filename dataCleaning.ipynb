# %%
import pandas as pd
import numpy as np
import re

# %%
whole_data = pd.read_excel('D:\OneDrive - Mapúa University\Desktop Folder\Self Projects\Ph-Real-Estate\csv files\DataGathered.xlsx')

# %%
# Checking of column names
whole_data.columns.tolist()
# Out:
# ['link',
#  'title',
#  'location',
#  'price',
#  'propertyType',
#  'offerType',
#  'Bedrooms',
#  'Bathrooms',
#  'Floor area (m²)',
#  'Land Size (m²)',
#  "Maid's room",
#  'Fully furnished',
#  'Fully fenced',
#  'Garage',
#  'Price conditions',
#  'Car Spaces',
#  'Price range',
#  'Available from',
#  'Attic',
#  'Open space',
#  'Subdivision name',
#  'Landscaped Garden',
#  'Carport',
#  'Build (Year)',
#  'Terrace',
#  'Open car spaces',
#  'Parking lot',
#  'Balcony',
#  'Maids room',
#  'Library',
#  'Air conditioning',
#  'Bar',
#  'Built-in wardrobes',
#  'Central Air Conditioning',
#  'Lounge',
#  'Storage Room',
#  'Courtyard',
#  'Basketball court',
#  'Garden',
#  'Classification',
#  'Ensuite',
#  'Secure parking',
#  'Shower Rooms',
#  'Block and Lot/Unit Number',
#  'Wi-Fi',
#  'Multi-purpose lawn',
#  'Jogging path',
#  'Parks',
#  'Swimming pool',
#  '24-hour security',
#  'Clubhouse',
#  'Playground',
#  'Rooms (total)',
#  'Gazebos',
#  'Function area',
#  'Sqm Range',
#  'Broadband internet available',
#  'Pay TV access',
#  'Entertainment room',
#  'Study room',
#  'Fire Alarm',
#  'Lanai',
#  'Powder room',
#  'CCTV',
#  'Remote garage',
#  'Alarm System',
#  'Basement',
#  "Driver's room",
#  'Ducted cooling',
#  'Ducted vacuum system',
#  'Fireplace',
#  'Floorboards',
#  'Gym',
#  'Jacuzzi',
#  'Sauna',
#  'Smoke detector',
#  'Split-system heating',
#  'Badminton court',
#  'Helipad',
#  'Sports facilities',
#  'Tennis court',
#  'Volleyball Court',
#  'Baths',
#  'Condominium Name',
#  'Gymnasium',
#  'Indoor Pool',
#  'Billiards table',
#  'Club House',
#  'Elevators',
#  'Fire exits',
#  'Fitness center',
#  'Function Room',
#  'Indoor spa',
#  'Lobby',
#  'Reception Area',
#  'Shower rooms',
#  'Social hall',
#  'Unit/Floor Number',
#  'Total Floors',
#  'Fire sprinkler system',
#  'Meeting rooms',
#  'Deck',
#  'Central air conditioning',
#  'Drying Area',
#  'Indoor Tree House',
#  'Deposit / Bond',
#  'Shops',
#  'Basement Parking',
#  'Business Center',
#  'Health Club',
#  'Intercom',
#  'Maids Room',
#  'Multi-Purpose Hall',
#  'Tower Name/Number',
#  'Laundry Area',
#  'Spa',
#  'Block and Lot/Unit/Floor Number',
#  'Gazebo',
#  'Utility room',
#  'Golf Area',
#  'Outdoor spa',
#  'Game Room',
#  'Clinic',
#  'Hydronic heating',
#  'Daycare Center',
#  'Pond',
#  'Drying area',
#  'Pool bar',
#  'Amphitheater',
#  'Sky lounge',
#  'Study area',
#  'Gas heating',
#  'Open fireplace',
#  'Theater',
#  'Floor',
#  'Floor area (m┬▓)',
#  'Unnamed: 136',
#  'Land Size (m┬▓)',
#  'Floor area (m¬≤)',
#  'Land Size (m¬≤)',
#  'Floor area (môý)',
#  'Land Size (môý)',
#  'Floor area (mÂĠ)',
#  'Land Size (mÂĠ)',
#  'Floor area (mĀ²)',
#  'Land Size (mĀ²)',
#  'Floor area (mÂē)',
#  'Land Size (mÂē)']

# %% [markdown]
# ## Renaming of Columns to standard ASCII Code

# %%
# Renaming of all column names to standard ASCII Code
for col in whole_data:
    whole_data = whole_data.rename(columns={col: re.sub(r'[^\x00-\x7F]', r'', col,  count =0, flags=re.IGNORECASE)})

# %% [markdown]
# ## Replacing the character 'void' with null

# %%
whole_data.head()
# Out:
#                                                 link  \
# 0  https://www.lamudi.com.ph/house-and-lot-for-sa...
# 1  https://www.lamudi.com.ph/house-and-lot-for-sa...
# 2  https://www.lamudi.com.ph/l-r-1-900-acquired-p...
# 3  https://www.lamudi.com.ph/msg-08-0410-foreclos...
# 4  https://www.lamudi.com.ph/rest-house-for-sale-...
#
#                                                title  \
# 0  House and Lot for Sale in Barangay Gaddani, Ta...
# 1       house and lot 3 bedroom  for sale  tagaytay.
# 2  L-R-1-900- Acquired Property for Sale in Lot 1...
# 3  MSG-08-0410: Foreclosed Residential - House & ...
# 4  4BR Rest House Rush for sale at Nalvo, Santa M...
#
#                      location                    price propertyType offerType  \
# 0              Gaddani, Tayum              ₱ 5,000,000        house       buy
# 1          Tagaytay, San Juan             ₱ 12,000,000        house       buy
# 2  Laslasong Sur, Santa Maria              ₱ 4,763,300        house       buy
# 3  Laslasong Sur, Santa Maria              ₱ 4,763,300        house       buy
# 4          Nalvo, Santa Maria  Contact agent for price        house       buy
#
#   Bedrooms Bathrooms Floor area (m) Land Size (m)  ... Floor area (m)  \
# 0        5         4            250          1312  ...           void
# 1        3         2            200           259  ...           void
# 2     void      void            225          1382  ...           void
# 3     void      void            225          1382  ...           void
# 4        4         3           void         33000  ...           void
#
#   Land Size (m) Floor area (m) Land Size (m) Floor area (m) Land Size (m)  \
# 0          void           void          void           void          void
# 1          void           void          void           void          void
# 2          void           void          void           void          void
# 3          void           void          void           void          void
# 4          void           void          void           void          void
#
#   Floor area (m) Land Size (m) Floor area (m) Land Size (m)
# 0           void          void           void          void
# 1           void          void           void          void
# 2           void          void           void          void
# 3           void          void           void          void
# 4           void          void           void          void
#
# [5 rows x 148 columns]

# %%
whole_data = whole_data.replace('void', np.nan)

# %%
whole_data.head()
# Out:
#                                                 link  \
# 0  https://www.lamudi.com.ph/house-and-lot-for-sa...
# 1  https://www.lamudi.com.ph/house-and-lot-for-sa...
# 2  https://www.lamudi.com.ph/l-r-1-900-acquired-p...
# 3  https://www.lamudi.com.ph/msg-08-0410-foreclos...
# 4  https://www.lamudi.com.ph/rest-house-for-sale-...
#
#                                                title  \
# 0  House and Lot for Sale in Barangay Gaddani, Ta...
# 1       house and lot 3 bedroom  for sale  tagaytay.
# 2  L-R-1-900- Acquired Property for Sale in Lot 1...
# 3  MSG-08-0410: Foreclosed Residential - House & ...
# 4  4BR Rest House Rush for sale at Nalvo, Santa M...
#
#                      location                    price propertyType offerType  \
# 0              Gaddani, Tayum              ₱ 5,000,000        house       buy
# 1          Tagaytay, San Juan             ₱ 12,000,000        house       buy
# 2  Laslasong Sur, Santa Maria              ₱ 4,763,300        house       buy
# 3  Laslasong Sur, Santa Maria              ₱ 4,763,300        house       buy
# 4          Nalvo, Santa Maria  Contact agent for price        house       buy
#
#   Bedrooms Bathrooms  Floor area (m)  Land Size (m)  ...  Floor area (m)  \
# 0        5         4             250           1312  ...             NaN
# 1        3         2             200            259  ...             NaN
# 2      NaN       NaN             225           1382  ...             NaN
# 3      NaN       NaN             225           1382  ...             NaN
# 4        4         3             NaN          33000  ...             NaN
#
#    Land Size (m)  Floor area (m)  Land Size (m)  Floor area (m)  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    Land Size (m)  Floor area (m)  Land Size (m)  Floor area (m)  Land Size (m)
# 0            NaN             NaN            NaN             NaN            NaN
# 1            NaN             NaN            NaN             NaN            NaN
# 2            NaN             NaN            NaN             NaN            NaN
# 3            NaN             NaN            NaN             NaN            NaN
# 4            NaN             NaN            NaN             NaN            NaN
#
# [5 rows x 148 columns]

# %% [markdown]
# Looking at the data, there appears to be columns with the same name *Floor area (m)* and *Land Size (m)*
#
# Investigating these values, it appears that the separate columns have been created due to the different unicode that the last columns used. With this, we would be concatinating all of their values together

# %% [markdown]
# ## Checking of Floor area Columns

# %%
whole_data['Floor area (m)'].iloc[:, 0:6].describe()
# Out:
#        Floor area (m) Floor area (m) Floor area (m) Floor area (m)  \
# count           76551            129             22             88
# unique           3969             59             15             24
# top               200            112            140            140
# freq             1823             11              3             33
#
#        Floor area (m) Floor area (m)
# count               1              1
# unique              1              1
# top               590            130
# freq                1              1

# %%
whole_data['Floor area (m)'].iloc[:, 0:6][~whole_data['Floor area (m)'].iloc[:, 1].isnull()].head()
# Out:
#      Floor area (m) Floor area (m) Floor area (m) Floor area (m)  \
# 1739            NaN             39            NaN            NaN
# 1974            NaN            304            NaN            NaN
# 2449            NaN            299            NaN            NaN
# 2979            NaN            304            NaN            NaN
# 3390            NaN             96            NaN            NaN
#
#      Floor area (m) Floor area (m)
# 1739            NaN            NaN
# 1974            NaN            NaN
# 2449            NaN            NaN
# 2979            NaN            NaN
# 3390            NaN            NaN

# %%
whole_data['Floor area (m)'].iloc[:, 0:6][~whole_data['Floor area (m)'].iloc[:, 2].isnull()].head()
# Out:
#       Floor area (m) Floor area (m) Floor area (m) Floor area (m)  \
# 4641             NaN            NaN            140            NaN
# 10985            NaN            NaN          106.5            NaN
# 31351            NaN            NaN             92            NaN
# 41799            NaN            NaN            150            NaN
# 42045            NaN            NaN            140            NaN
#
#       Floor area (m) Floor area (m)
# 4641             NaN            NaN
# 10985            NaN            NaN
# 31351            NaN            NaN
# 41799            NaN            NaN
# 42045            NaN            NaN

# %%
whole_data['Floor area (m)'].iloc[:, 0:6][~whole_data['Floor area (m)'].iloc[:, 3].isnull()].head()
# Out:
#       Floor area (m) Floor area (m) Floor area (m) Floor area (m)  \
# 4644             NaN            NaN            NaN            150
# 11193            NaN            NaN            NaN            590
# 28181            NaN            NaN            NaN            150
# 29733            NaN            NaN            NaN            140
# 32732            NaN            NaN            NaN            125
#
#       Floor area (m) Floor area (m)
# 4644             NaN            NaN
# 11193            NaN            NaN
# 28181            NaN            NaN
# 29733            NaN            NaN
# 32732            NaN            NaN

# %% [markdown]
# ## Checking of Land Size columns

# %%
whole_data['Land Size (m)'].iloc[:, 0:6][~whole_data['Land Size (m)'].iloc[:, 1].isnull()].head()
# Out:
#      Land Size (m) Land Size (m) Land Size (m) Land Size (m) Land Size (m)  \
# 2449           NaN           278           NaN           NaN           NaN
# 4323           NaN           200           NaN           NaN           NaN
# 4559           NaN           150           NaN           NaN           NaN
# 4584           NaN           135           NaN           NaN           NaN
# 4630           NaN           130           NaN           NaN           NaN
#
#      Land Size (m)
# 2449           NaN
# 4323           NaN
# 4559           NaN
# 4584           NaN
# 4630           NaN

# %%
whole_data['Land Size (m)'].iloc[:, 0:6][~whole_data['Land Size (m)'].iloc[:, 2].isnull()].head()
# Out:
#       Land Size (m) Land Size (m) Land Size (m) Land Size (m) Land Size (m)  \
# 4641            NaN           NaN           133           NaN           NaN
# 10985           NaN           NaN           104           NaN           NaN
# 31351           NaN           NaN            86           NaN           NaN
# 41799           NaN           NaN            93           NaN           NaN
# 42045           NaN           NaN            80           NaN           NaN
#
#       Land Size (m)
# 4641            NaN
# 10985           NaN
# 31351           NaN
# 41799           NaN
# 42045           NaN

# %%
whole_data['Land Size (m)'].iloc[:, 0:6][~whole_data['Land Size (m)'].iloc[:, 3].isnull()]
# Out:
#       Land Size (m) Land Size (m) Land Size (m) Land Size (m) Land Size (m)  \
# 4644            NaN           NaN           NaN           143           NaN
# 11193           NaN           NaN           NaN           656           NaN
# 28181           NaN           NaN           NaN           107           NaN
# 29733           NaN           NaN           NaN            80           NaN
# 32732           NaN           NaN           NaN            80           NaN
# ...             ...           ...           ...           ...           ...
# 68004           NaN           NaN           NaN            48           NaN
# 76460           NaN           NaN           NaN           104           NaN
# 76464           NaN           NaN           NaN           120           NaN
# 76524           NaN           NaN           NaN           120           NaN
# 76538           NaN           NaN           NaN           101           NaN
#
#       Land Size (m)
# 4644            NaN
# 11193           NaN
# 28181           NaN
# 29733           NaN
# 32732           NaN
# ...             ...
# 68004           NaN
# 76460           NaN
# 76464           NaN
# 76524           NaN
# 76538           NaN
#
# [84 rows x 6 columns]

# %% [markdown]
# ## Concatenating values the different Land Size and Floor Area columns to a single columns

# %%
for i in range(1, 7):
    
    for j, row in whole_data['Floor area (m)'][~whole_data['Floor area (m)'].iloc[:, i].isnull()].iterrows():
        whole_data.at[j,['Floor area (m)'][0]] = whole_data.iloc[j]['Floor area (m)'][i]
    for j, row in whole_data['Land Size (m)'][~whole_data['Land Size (m)'].iloc[:, i].isnull()].iterrows():
        whole_data.at[j,['Land Size (m)'][0]] = whole_data.iloc[j]['Land Size (m)'][i]
    
# trial = whole_data.drop(whole_data.iloc[:, -11:],axis = 1, inplace= True)

# %%
whole_data['Floor area (m)']
# Out:
#       Floor area (m) Floor area (m) Floor area (m) Floor area (m)  \
# 0                250            NaN            NaN            NaN
# 1                200            NaN            NaN            NaN
# 2                225            NaN            NaN            NaN
# 3                225            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 77803            120            NaN            NaN            NaN
# 77804            350            NaN            NaN            NaN
# 77805          40.31            NaN            NaN            NaN
# 77806          32.07            NaN            NaN            NaN
# 77807          22.38            NaN            NaN            NaN
#
#       Floor area (m) Floor area (m) Floor area (m)
# 0                NaN            NaN            NaN
# 1                NaN            NaN            NaN
# 2                NaN            NaN            NaN
# 3                NaN            NaN            NaN
# 4                NaN            NaN            NaN
# ...              ...            ...            ...
# 77803            NaN            NaN            NaN
# 77804            NaN            NaN            NaN
# 77805            NaN            NaN            NaN
# 77806            NaN            NaN            NaN
# 77807            NaN            NaN            NaN
#
# [77808 rows x 7 columns]

# %%
# Deleting of extra Floor area columns and Land Size Columns
cols = []
cFloor = False
cLand = False
for column in whole_data.columns:
    if column == 'Floor area (m)':
        if cFloor:
            cols.append(f'Floor area (m) Delete')
            continue
        cFloor = True
        cols.append(column)
        continue
    if column == 'Land Size (m)':
        if cLand:
            cols.append('Land Size (m) Delete')
            continue
        cLand = True
        cols.append(column)
        continue
    cols.append(column)

# Replace columns in whole_data to cols
whole_data.columns = cols
whole_data.drop(['Floor area (m) Delete', 'Land Size (m) Delete'], axis=1, inplace=True)
# Delete variables used to free memory
del cLand, cFloor, cols

# %%
whole_data.head()
# Out:
#                                                 link  \
# 0  https://www.lamudi.com.ph/house-and-lot-for-sa...
# 1  https://www.lamudi.com.ph/house-and-lot-for-sa...
# 2  https://www.lamudi.com.ph/l-r-1-900-acquired-p...
# 3  https://www.lamudi.com.ph/msg-08-0410-foreclos...
# 4  https://www.lamudi.com.ph/rest-house-for-sale-...
#
#                                                title  \
# 0  House and Lot for Sale in Barangay Gaddani, Ta...
# 1       house and lot 3 bedroom  for sale  tagaytay.
# 2  L-R-1-900- Acquired Property for Sale in Lot 1...
# 3  MSG-08-0410: Foreclosed Residential - House & ...
# 4  4BR Rest House Rush for sale at Nalvo, Santa M...
#
#                      location                    price propertyType offerType  \
# 0              Gaddani, Tayum              ₱ 5,000,000        house       buy
# 1          Tagaytay, San Juan             ₱ 12,000,000        house       buy
# 2  Laslasong Sur, Santa Maria              ₱ 4,763,300        house       buy
# 3  Laslasong Sur, Santa Maria              ₱ 4,763,300        house       buy
# 4          Nalvo, Santa Maria  Contact agent for price        house       buy
#
#   Bedrooms Bathrooms Floor area (m) Land Size (m)  ...  Drying area Pool bar  \
# 0        5         4            250          1312  ...          NaN      NaN
# 1        3         2            200           259  ...          NaN      NaN
# 2      NaN       NaN            225          1382  ...          NaN      NaN
# 3      NaN       NaN            225          1382  ...          NaN      NaN
# 4        4         3            NaN         33000  ...          NaN      NaN
#
#    Amphitheater  Sky lounge Study area Gas heating Open fireplace Theater  \
# 0           NaN         NaN        NaN         NaN            NaN     NaN
# 1           NaN         NaN        NaN         NaN            NaN     NaN
# 2           NaN         NaN        NaN         NaN            NaN     NaN
# 3           NaN         NaN        NaN         NaN            NaN     NaN
# 4           NaN         NaN        NaN         NaN            NaN     NaN
#
#    Floor  Unnamed: 136
# 0    NaN           NaN
# 1    NaN           NaN
# 2    NaN           NaN
# 3    NaN           NaN
# 4    NaN           NaN
#
# [5 rows x 136 columns]

# %% [markdown]
# ## Cleaning of Data

# %% [markdown]
# As it can be seen, the data is not yet clean where the price can contain the Pesos sign, or is tagged as 'Contact agent for price', or can contain new lines. Each of the columns should then be cleaned first before further processing should be done

# %%
# Checking of columns present
whole_data.dtypes
# Out:
# link               object
# title              object
# location           object
# price              object
# propertyType       object
#                    ...
# Gas heating       float64
# Open fireplace    float64
# Theater           float64
# Floor              object
# Unnamed: 136      float64
# Length: 136, dtype: object

# %% [markdown]
# Changing dtype of Price Column

# %%
# Removing all \n in all of the columns
whole_data = whole_data.replace('\n', '', regex=True)

# Removing prices with 'Contact agent for price'
whole_data = whole_data.loc[whole_data['price'] != 'Contact agent for price']

# Removing the prices that were converted into dollars
whole_data['price'] = whole_data['price'].replace('\$(.*)', '', regex=True)

# Putting New Column named Monthly Payment for prices that has the string 'Monthly' in it
# Same goes with yearly and daily payment
whole_data['Monthly Payment'] = whole_data['price'].str.contains('Monthly')
whole_data['Yearly Payment'] = whole_data['price'].str.contains('Yearly')
whole_data['Daily Payment'] = whole_data['price'].str.contains('Daily')

# Removing Monthly, Yearly, and Daily on the price string
whole_data['price'] = whole_data['price'].replace('Monthly', '', regex=True)
whole_data['price'] = whole_data['price'].replace('Yearly', '', regex=True)
whole_data['price'] = whole_data['price'].replace('Daily', '', regex=True)

# Removal of any characters that are not digits
whole_data['price'] = whole_data['price'].replace('(\D)*', '', regex=True)

# Removing rows with no more data in the column of price - ''
whole_data = whole_data.loc[whole_data['price'] != '']

# Conversion of price to float
whole_data['price'].astype('float')

# %% [markdown]
# Changing dtype of Floor area (m) column and Land Size (m) column

# %%
# Floor Area
whole_data['Floor area (m)'] = whole_data['Floor area (m)'].replace(',', '', regex=True)
whole_data['Floor area (m)'].astype('float')
# Land Size
whole_data['Land Size (m)'] = whole_data['Land Size (m)'].replace(',', '', regex=True)
whole_data['Land Size (m)'].astype('float')

# %%
whole_data['Bedrooms'].astype('float').apply(np.floor).astype('Int64')
whole_data['Bathrooms'].astype('float').apply(np.floor).astype('Int64')
whole_data["Maid's room"].astype('float').apply(np.floor).astype('Int64')
# Out:
# 0           5
# 1           3
# 2        <NA>
# 3        <NA>
# 5           4
#          ...
# 77801       4
# 77802       3
# 77803       2
# 77806       2
# 77807       1
# Name: Bedrooms, Length: 74985, dtype: Int64

# %%
whole_data.loc[whole_data['Fully furnished'] == 'No']
# Out:
#                                                     link  \
# 7      https://www.lamudi.com.ph/2-story-house-lot-in...
# 8      https://www.lamudi.com.ph/bungalow-house-with-...
# 14     https://www.lamudi.com.ph/3-bedroom-house-and-...
# 23     https://www.lamudi.com.ph/3-bedroom-house-lot-...
# 28     https://www.lamudi.com.ph/house-property-4-bed...
# ...                                                  ...
# 77776  https://www.lamudi.com.ph/5-bedroom-unit-avail...
# 77779  https://www.lamudi.com.ph/for-sale-3-bedroom-d...
# 77781  https://www.lamudi.com.ph/affordable-house-and...
# 77784  https://www.lamudi.com.ph/corner-house-for-sal...
# 77785  https://www.lamudi.com.ph/5-bedroom-bungalow-h...
#
#                                                    title  \
# 7      For Sale Fully Furnished 2-Story House & Lot i...
# 8                    Bungalow House with Wide Open Space
# 14     3 Bedroom House and Lot for Sale Calayab, Laoa...
# 23     3 Bedroom House & Lot For Sale in Laoag, Iloco...
# 28     House property 4 bedrooms for sale in Bgy.No.1...
# ...                                                  ...
# 77776  For Sale 5 Bedroom House at Camella Subic in S...
# 77779  For Sale 3 Bedroom Duplex Style in Tierra Verd...
# 77781  For Sale: Affordable House and Lot in Lumina S...
# 77784  Corner 4 Bedrooms House and lot for Sale insid...
# 77785  5-Bedroom Bungalow House and Lot for Sale in F...
#
#                                 location     price propertyType offerType  \
# 7                     Pantay Daya, Vigan   3700000        house       buy
# 8                Nanerman, Santo Domingo   3800000        house       buy
# 14           Bgy. No. 37  Calayab, Laoag   2800000        house       buy
# 23     Bgy. No. 11  Santa Balbina, Laoag  19900000        house       buy
# 28        Bgy. No. 12  San Isidro, Laoag  12000000        house       buy
# ...                                  ...       ...          ...       ...
# 77776          Aningway Sacatihan, Subic   8989000        house       buy
# 77779                 Mangan-Vaca, Subic   4636000        house       buy
# 77781                   Pamatawan, Subic   1944000        house       buy
# 77784                    Anunas, Angeles  12000000        house       buy
# 77785                    Anunas, Angeles  17000000        house       buy
#
#       Bedrooms Bathrooms Floor area (m) Land Size (m)  ...  Sky lounge  \
# 7            3         2             82           200  ...         NaN
# 8            3         2            120           800  ...         NaN
# 14           3         2             70           223  ...         NaN
# 23           3         1            200           398  ...         NaN
# 28           4         2            200          1431  ...         NaN
# ...        ...       ...            ...           ...  ...         ...
# 77776        5         3            166           143  ...         NaN
# 77779        3         2             61           117  ...         NaN
# 77781        2         1             35            54  ...         NaN
# 77784        4         2            300           400  ...         NaN
# 77785        5         4            400           600  ...         NaN
#
#       Study area  Gas heating  Open fireplace Theater Floor Unnamed: 136  \
# 7            NaN          NaN             NaN     NaN   NaN          NaN
# 8            NaN          NaN             NaN     NaN   NaN          NaN
# 14           NaN          NaN             NaN     NaN   NaN          NaN
# 23           NaN          NaN             NaN     NaN   NaN          NaN
# 28           NaN          NaN             NaN     NaN   NaN          NaN
# ...          ...          ...             ...     ...   ...          ...
# 77776        NaN          NaN             NaN     NaN   NaN          NaN
# 77779        NaN          NaN             NaN     NaN   NaN          NaN
# 77781        NaN          NaN             NaN     NaN   NaN          NaN
# 77784        NaN          NaN             NaN     NaN   NaN          NaN
# 77785        NaN          NaN             NaN     NaN   NaN          NaN
#
#       Monthly Payment  Yearly Payment  Daily Payment
# 7               False           False          False
# 8               False           False          False
# 14              False           False          False
# 23              False           False          False
# 28              False           False          False
# ...               ...             ...            ...
# 77776           False           False          False
# 77779           False           False          False
# 77781           False           False          False
# 77784           False           False          False
# 77785           False           False          False
#
# [17967 rows x 139 columns]

# %%
whole_data.columns.tolist()
# Out:
# ['link',
#  'title',
#  'location',
#  'price',
#  'propertyType',
#  'offerType',
#  'Bedrooms',
#  'Bathrooms',
#  'Floor area (m)',
#  'Land Size (m)',
#  "Maid's room",
#  'Fully furnished',
#  'Fully fenced',
#  'Garage',
#  'Price conditions',
#  'Car Spaces',
#  'Price range',
#  'Available from',
#  'Attic',
#  'Open space',
#  'Subdivision name',
#  'Landscaped Garden',
#  'Carport',
#  'Build (Year)',
#  'Terrace',
#  'Open car spaces',
#  'Parking lot',
#  'Balcony',
#  'Maids room',
#  'Library',
#  'Air conditioning',
#  'Bar',
#  'Built-in wardrobes',
#  'Central Air Conditioning',
#  'Lounge',
#  'Storage Room',
#  'Courtyard',
#  'Basketball court',
#  'Garden',
#  'Classification',
#  'Ensuite',
#  'Secure parking',
#  'Shower Rooms',
#  'Block and Lot/Unit Number',
#  'Wi-Fi',
#  'Multi-purpose lawn',
#  'Jogging path',
#  'Parks',
#  'Swimming pool',
#  '24-hour security',
#  'Clubhouse',
#  'Playground',
#  'Rooms (total)',
#  'Gazebos',
#  'Function area',
#  'Sqm Range',
#  'Broadband internet available',
#  'Pay TV access',
#  'Entertainment room',
#  'Study room',
#  'Fire Alarm',
#  'Lanai',
#  'Powder room',
#  'CCTV',
#  'Remote garage',
#  'Alarm System',
#  'Basement',
#  "Driver's room",
#  'Ducted cooling',
#  'Ducted vacuum system',
#  'Fireplace',
#  'Floorboards',
#  'Gym',
#  'Jacuzzi',
#  'Sauna',
#  'Smoke detector',
#  'Split-system heating',
#  'Badminton court',
#  'Helipad',
#  'Sports facilities',
#  'Tennis court',
#  'Volleyball Court',
#  'Baths',
#  'Condominium Name',
#  'Gymnasium',
#  'Indoor Pool',
#  'Billiards table',
#  'Club House',
#  'Elevators',
#  'Fire exits',
#  'Fitness center',
#  'Function Room',
#  'Indoor spa',
#  'Lobby',
#  'Reception Area',
#  'Shower rooms',
#  'Social hall',
#  'Unit/Floor Number',
#  'Total Floors',
#  'Fire sprinkler system',
#  'Meeting rooms',
#  'Deck',
#  'Central air conditioning',
#  'Drying Area',
#  'Indoor Tree House',
#  'Deposit / Bond',
#  'Shops',
#  'Basement Parking',
#  'Business Center',
#  'Health Club',
#  'Intercom',
#  'Maids Room',
#  'Multi-Purpose Hall',
#  'Tower Name/Number',
#  'Laundry Area',
#  'Spa',
#  'Block and Lot/Unit/Floor Number',
#  'Gazebo',
#  'Utility room',
#  'Golf Area',
#  'Outdoor spa',
#  'Game Room',
#  'Clinic',
#  'Hydronic heating',
#  'Daycare Center',
#  'Pond',
#  'Drying area',
#  'Pool bar',
#  'Amphitheater',
#  'Sky lounge',
#  'Study area',
#  'Gas heating',
#  'Open fireplace',
#  'Theater',
#  'Floor',
#  'Unnamed: 136',
#  'Monthly Payment',
#  'Yearly Payment',
#  'Daily Payment']

# %% [markdown]
# ## Separation of data

# %% [markdown]
# As the details and amenities offered from houses, condominiums, and apartments are different from one another, we would be separating these three to their own dataframes

# %%
house_data = whole_data.loc[whole_data['propertyType'] == 'house']
condo_data = whole_data.loc[whole_data['propertyType'] == 'condominium']
apart_data = whole_data.loc[whole_data['propertyType'] == 'apartment']
