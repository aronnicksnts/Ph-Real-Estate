# %%
import pandas as pd
import numpy as np
import re

# %%
whole_data = pd.read_excel('D:\OneDrive - Mapúa University\Desktop Folder\Self Projects\Ph-Real-Estate\csv files\DataGathered.xlsx')

# %%
# Knowing of column names
whole_data.columns.tolist()
# Out:
# ['link',
#  'title',
#  'location',
#  'price',
#  'propertyType',
#  'offerType',
#  'Bedrooms',
#  'Bathrooms',
#  'Floor area (m²)',
#  'Land Size (m²)',
#  "Maid's room",
#  'Fully furnished',
#  'Fully fenced',
#  'Garage',
#  'Price conditions',
#  'Car Spaces',
#  'Price range',
#  'Available from',
#  'Attic',
#  'Open space',
#  'Subdivision name',
#  'Landscaped Garden',
#  'Carport',
#  'Build (Year)',
#  'Terrace',
#  'Open car spaces',
#  'Parking lot',
#  'Balcony',
#  'Maids room',
#  'Library',
#  'Air conditioning',
#  'Bar',
#  'Built-in wardrobes',
#  'Central Air Conditioning',
#  'Lounge',
#  'Storage Room',
#  'Courtyard',
#  'Basketball court',
#  'Garden',
#  'Classification',
#  'Ensuite',
#  'Secure parking',
#  'Shower Rooms',
#  'Block and Lot/Unit Number',
#  'Wi-Fi',
#  'Multi-purpose lawn',
#  'Jogging path',
#  'Parks',
#  'Swimming pool',
#  '24-hour security',
#  'Clubhouse',
#  'Playground',
#  'Rooms (total)',
#  'Gazebos',
#  'Function area',
#  'Sqm Range',
#  'Broadband internet available',
#  'Pay TV access',
#  'Entertainment room',
#  'Study room',
#  'Fire Alarm',
#  'Lanai',
#  'Powder room',
#  'CCTV',
#  'Remote garage',
#  'Alarm System',
#  'Basement',
#  "Driver's room",
#  'Ducted cooling',
#  'Ducted vacuum system',
#  'Fireplace',
#  'Floorboards',
#  'Gym',
#  'Jacuzzi',
#  'Sauna',
#  'Smoke detector',
#  'Split-system heating',
#  'Badminton court',
#  'Helipad',
#  'Sports facilities',
#  'Tennis court',
#  'Volleyball Court',
#  'Baths',
#  'Condominium Name',
#  'Gymnasium',
#  'Indoor Pool',
#  'Billiards table',
#  'Club House',
#  'Elevators',
#  'Fire exits',
#  'Fitness center',
#  'Function Room',
#  'Indoor spa',
#  'Lobby',
#  'Reception Area',
#  'Shower rooms',
#  'Social hall',
#  'Unit/Floor Number',
#  'Total Floors',
#  'Fire sprinkler system',
#  'Meeting rooms',
#  'Deck',
#  'Central air conditioning',
#  'Drying Area',
#  'Indoor Tree House',
#  'Deposit / Bond',
#  'Shops',
#  'Basement Parking',
#  'Business Center',
#  'Health Club',
#  'Intercom',
#  'Maids Room',
#  'Multi-Purpose Hall',
#  'Tower Name/Number',
#  'Laundry Area',
#  'Spa',
#  'Block and Lot/Unit/Floor Number',
#  'Gazebo',
#  'Utility room',
#  'Golf Area',
#  'Outdoor spa',
#  'Game Room',
#  'Clinic',
#  'Hydronic heating',
#  'Daycare Center',
#  'Pond',
#  'Drying area',
#  'Pool bar',
#  'Amphitheater',
#  'Sky lounge',
#  'Study area',
#  'Gas heating',
#  'Open fireplace',
#  'Theater',
#  'Floor',
#  'Floor area (m┬▓)',
#  'Unnamed: 136',
#  'Land Size (m┬▓)',
#  'Floor area (m¬≤)',
#  'Land Size (m¬≤)',
#  'Floor area (môý)',
#  'Land Size (môý)',
#  'Floor area (mÂĠ)',
#  'Land Size (mÂĠ)',
#  'Floor area (mĀ²)',
#  'Land Size (mĀ²)',
#  'Floor area (mÂē)',
#  'Land Size (mÂē)']

# %% [markdown]
# ## Renaming of Columns to standard ASCII Code

# %%
# Renaming of all column names to standard ASCII Code
for col in whole_data:
    whole_data = whole_data.rename(columns={col: re.sub(r'[^\x00-\x7F]', r'', col,  count =0, flags=re.IGNORECASE)})

# %%
whole_data.columns.tolist()
# Out:
# ['link',
#  'title',
#  'location',
#  'price',
#  'propertyType',
#  'offerType',
#  'Bedrooms',
#  'Bathrooms',
#  'Floor area (m)',
#  'Land Size (m)',
#  "Maid's room",
#  'Fully furnished',
#  'Fully fenced',
#  'Garage',
#  'Price conditions',
#  'Car Spaces',
#  'Price range',
#  'Available from',
#  'Attic',
#  'Open space',
#  'Subdivision name',
#  'Landscaped Garden',
#  'Carport',
#  'Build (Year)',
#  'Terrace',
#  'Open car spaces',
#  'Parking lot',
#  'Balcony',
#  'Maids room',
#  'Library',
#  'Air conditioning',
#  'Bar',
#  'Built-in wardrobes',
#  'Central Air Conditioning',
#  'Lounge',
#  'Storage Room',
#  'Courtyard',
#  'Basketball court',
#  'Garden',
#  'Classification',
#  'Ensuite',
#  'Secure parking',
#  'Shower Rooms',
#  'Block and Lot/Unit Number',
#  'Wi-Fi',
#  'Multi-purpose lawn',
#  'Jogging path',
#  'Parks',
#  'Swimming pool',
#  '24-hour security',
#  'Clubhouse',
#  'Playground',
#  'Rooms (total)',
#  'Gazebos',
#  'Function area',
#  'Sqm Range',
#  'Broadband internet available',
#  'Pay TV access',
#  'Entertainment room',
#  'Study room',
#  'Fire Alarm',
#  'Lanai',
#  'Powder room',
#  'CCTV',
#  'Remote garage',
#  'Alarm System',
#  'Basement',
#  "Driver's room",
#  'Ducted cooling',
#  'Ducted vacuum system',
#  'Fireplace',
#  'Floorboards',
#  'Gym',
#  'Jacuzzi',
#  'Sauna',
#  'Smoke detector',
#  'Split-system heating',
#  'Badminton court',
#  'Helipad',
#  'Sports facilities',
#  'Tennis court',
#  'Volleyball Court',
#  'Baths',
#  'Condominium Name',
#  'Gymnasium',
#  'Indoor Pool',
#  'Billiards table',
#  'Club House',
#  'Elevators',
#  'Fire exits',
#  'Fitness center',
#  'Function Room',
#  'Indoor spa',
#  'Lobby',
#  'Reception Area',
#  'Shower rooms',
#  'Social hall',
#  'Unit/Floor Number',
#  'Total Floors',
#  'Fire sprinkler system',
#  'Meeting rooms',
#  'Deck',
#  'Central air conditioning',
#  'Drying Area',
#  'Indoor Tree House',
#  'Deposit / Bond',
#  'Shops',
#  'Basement Parking',
#  'Business Center',
#  'Health Club',
#  'Intercom',
#  'Maids Room',
#  'Multi-Purpose Hall',
#  'Tower Name/Number',
#  'Laundry Area',
#  'Spa',
#  'Block and Lot/Unit/Floor Number',
#  'Gazebo',
#  'Utility room',
#  'Golf Area',
#  'Outdoor spa',
#  'Game Room',
#  'Clinic',
#  'Hydronic heating',
#  'Daycare Center',
#  'Pond',
#  'Drying area',
#  'Pool bar',
#  'Amphitheater',
#  'Sky lounge',
#  'Study area',
#  'Gas heating',
#  'Open fireplace',
#  'Theater',
#  'Floor',
#  'Floor area (m)',
#  'Unnamed: 136',
#  'Land Size (m)',
#  'Floor area (m)',
#  'Land Size (m)',
#  'Floor area (m)',
#  'Land Size (m)',
#  'Floor area (m)',
#  'Land Size (m)',
#  'Floor area (m)',
#  'Land Size (m)',
#  'Floor area (m)',
#  'Land Size (m)']

# %% [markdown]
# ## Removing

# %% [markdown]
# Looking at the data, there appears to be columns with the same name *Floor area (m)* and *Land Size (m)*
# With this, we'll check if the data on the end columns has any significant data on them

# %%
whole_data['Floor area (m)'].iloc[:, 0:6].describe()
# Out:
#        Floor area (m) Floor area (m) Floor area (m) Floor area (m)  \
# count           77808          77808          77808          77808
# unique           3970             60             16             25
# top               200           void           void           void
# freq             1823          77679          77786          77720
#
#        Floor area (m) Floor area (m)
# count           77808          77808
# unique              2              2
# top              void           void
# freq            77807          77807
